# %%
print(8)
print(9)
print(10)
# Out:
# 8
# 9
# 10

# %%
print("my name is pawan")
# Out:
# my name is pawan

# %%
a1=89

# %%
print(a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6487c9f92f1c> in <module>
# ----> 1 print(a1)
#
# NameError: name 'a1' is not defined
